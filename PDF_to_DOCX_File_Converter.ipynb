# %% [markdown]
# ## For Multiple Files in Folder

# %%
from pdf2docx import Converter
import os

# %%
# # # dir_path for input reading and output files & a for loop # # #

path_input = r'C:\Users\Moin Dalvi\Downloads\Test Resumes'
path_output = r'C:\Users\Moin Dalvi\Downloads\Test Resumes'

# %%
for file in os.listdir(path_input):
    if file.endswith('.pdf'):
        final = os.path.join(path_input, file)
        cv = Converter(final)
        basename = os.path.splitext(file)[0]
        print(basename)
        cv.convert(path_output + '/' + basename+'.docx', start=0, end=None)
        cv.close()
# Out:
# [INFO] Start to convert C:\Users\Moin Dalvi\Downloads\Test Resumes\Reactjs Developer_Prabakaran_Musquare Technologies.pdf
# [INFO] [1/4] Opening document...
# [INFO] [2/4] Analyzing document...
# Reactjs Developer_Prabakaran_Musquare Technologies
# [INFO] [3/4] Parsing pages...
# [INFO] (1/2) Page 1
# [INFO] (2/2) Page 2
# [INFO] [4/4] Creating pages...
# [INFO] (1/2) Page 1
# [INFO] (2/2) Page 2
# [INFO] Terminated in 0.96s.
# [INFO] Start to convert C:\Users\Moin Dalvi\Downloads\Test Resumes\workday-hcm-consultant-1645597121.pdf
# [INFO] [1/4] Opening document...
# [INFO] [2/4] Analyzing document...
# [WARNING] 'modified' timestamp seems very low; regarding as unix timestamp
# [WARNING] 'modified' timestamp seems very low; regarding as unix timestamp
# [WARNING] 'modified' timestamp seems very low; regarding as unix timestamp
# workday-hcm-consultant-1645597121
# [INFO] [3/4] Parsing pages...
# [INFO] (1/2) Page 1
# [INFO] (2/2) Page 2
# [INFO] [4/4] Creating pages...
# ...

# %% [markdown]
# ## For Multiple Files in Multiple Folder

# %%
path_input = 'C:/Users\Moin Dalvi\Data_Science\Projects\Resume_Classification\Resumes_pdf/'
path_output = 'C:/Users\Moin Dalvi\Data_Science\Projects\Resume_Classification\Resumes_docx/'
for folder in os.listdir(path_input):
    folder_path = os.path.join(path_input, folder)
    for file in os.listdir(folder_path):
        if file.endswith('.pdf'):
            final_path = os.path.join(folder_path, file)
            cv = Converter(final_path)
            basename = os.path.splitext(file)[0]
            cv.convert(path_output + '/' + folder + '/' + basename+'.docx', start=0, end=None)
            cv.close()
# Out:
# [INFO] Start to convert C:/Users\Moin Dalvi\Data_Science\Projects\Resume_Classification\Resumes_pdf/Internship\Internship_Ravali_Musquare Technologies (1).pdf
# [INFO] [1/4] Opening document...
# [INFO] [2/4] Analyzing document...
# [INFO] [3/4] Parsing pages...
# [INFO] (1/4) Page 1
# [INFO] (2/4) Page 2
# [INFO] (3/4) Page 3
# [INFO] (4/4) Page 4
# [INFO] [4/4] Creating pages...
# [INFO] (1/4) Page 1
# [INFO] (2/4) Page 2
# [INFO] (3/4) Page 3
# [INFO] (4/4) Page 4
# [INFO] Terminated in 7.49s.
# [INFO] Start to convert C:/Users\Moin Dalvi\Data_Science\Projects\Resume_Classification\Resumes_pdf/Internship\Internship_Susovan Bag_Musquare Technologies.pdf
# [INFO] [1/4] Opening document...
# [INFO] [2/4] Analyzing document...
# [INFO] [3/4] Parsing pages...
# [INFO] (1/2) Page 1
# [INFO] (2/2) Page 2
# [INFO] [4/4] Creating pages...
# [INFO] (1/2) Page 1
# [INFO] (2/2) Page 2
# [INFO] Terminated in 0.36s.
# ...

# %%
import win32com.client
word = win32com.client.Dispatch("Word.Application")
word.visible = 1
pdfdoc = 'NewDoc.pdf'
todocx = 'NewDoc.docx'
wb1 = word.Documents.Open(pdfdoc)
wb1.SaveAs(todocx, FileFormat=16)  # file format for docx
wb1.Close()
word.Quit()

# %% [markdown]
# ## For Multiple Files in Multiple Folders personal work

# %%
# # # dir_path for input reading and output files & a for loop # # #

path_input = 'C:/Users\Moin Dalvi\Data_Science\Projects\Resume_Classification\Resumes_pdf/'
path_output = 'C:/Users\Moin Dalvi\Data_Science\Projects\Resume_Classification\Resumes_docx/'

# %%
for file in os.listdir(path_input):
        if file == 'Internship':
            final = os.path.join(path_input, file)
            for data in os.listdir(final):
                if data.endswith('.pdf'):
                    final_path = os.path.join(final, data)
                    cv = Converter(final_path)
                    basename = os.path.splitext(data)[0]
                    cv.convert(path_output + '/' + file + '/' + basename+'.docx', start=0, end=None)
                    cv.close()

# %%
for file in os.listdir(path_input):
        if file == 'Internship':
            final = os.path.join(path_input, file)
            for data in os.listdir(final):
                if data.endswith('.pdf'):
                    final_path = os.path.join(final, data)
                    cv = Converter(final_path)
                    basename = os.path.splitext(data)[0]
                    cv.convert(path_output + '/' + file + '/' + basename+'.docx', start=0, end=None)
                    cv.close()
# Out:
# [INFO] Start to convert C:/Users\Moin Dalvi\Data_Science\Projects\Resume_Classification\Resumes_pdf/Internship\Internship_Ravali_Musquare Technologies (1).pdf
# [INFO] [1/4] Opening document...
# [INFO] [2/4] Analyzing document...
# [INFO] [3/4] Parsing pages...
# [INFO] (1/4) Page 1
# [INFO] (2/4) Page 2
# [INFO] (3/4) Page 3
# [INFO] (4/4) Page 4
# [INFO] [4/4] Creating pages...
# [INFO] (1/4) Page 1
# [INFO] (2/4) Page 2
# [INFO] (3/4) Page 3
# [INFO] (4/4) Page 4
# [INFO] Terminated in 4.51s.
# [INFO] Start to convert C:/Users\Moin Dalvi\Data_Science\Projects\Resume_Classification\Resumes_pdf/Internship\Internship_Susovan Bag_Musquare Technologies.pdf
# [INFO] [1/4] Opening document...
# [INFO] [2/4] Analyzing document...
# [INFO] [3/4] Parsing pages...
# [INFO] (1/2) Page 1
# [INFO] (2/2) Page 2
# [INFO] [4/4] Creating pages...
# [INFO] (1/2) Page 1
# [INFO] (2/2) Page 2
# [INFO] Terminated in 0.36s.

# %%
for file in os.listdir(path_input):
        if file == 'Internship':
            final = os.path.join(path_input, file)
            for data in os.listdir(final):
                if data.endswith('.pdf'):
                    final_path = os.path.join(final, data)
                    cv = Converter(final_path)
                    basename = os.path.splitext(data)[0]
                    cv.convert(path_output + '/' + file + '/' + basename+'.docx', start=0, end=None)
                    cv.close()
        elif file == 'Peoplesoft Admin':
            final = os.path.join(path_input, file)
            for data in os.listdir(final):
                if data.endswith('.pdf'):
                    final_path = os.path.join(final, data)
                    cv = Converter(final_path)
                    basename = os.path.splitext(data)[0]
                    cv.convert(path_output + '/' + file + '/' + basename+'.docx', start=0, end=None)
                    cv.close()
        elif file == 'Peoplesoft DBA':
            final = os.path.join(path_input, file)
            for data in os.listdir(final):
                if data.endswith('.pdf'):
                    final_path = os.path.join(final, data)
                    cv = Converter(final_path)
                    basename = os.path.splitext(data)[0]
                    cv.convert(path_output + '/' + file + '/' + basename+'.docx', start=0, end=None)
                    cv.close()
        elif file == 'Peoplesoft Finance':
            final = os.path.join(path_input, file)
            for data in os.listdir(final):
                if data.endswith('.pdf'):
                    final_path = os.path.join(final, data)
                    cv = Converter(final_path)
                    basename = os.path.splitext(data)[0]
                    cv.convert(path_output + '/' + file + '/' + basename+'.docx', start=0, end=None)
                    cv.close()
        elif file == 'Peoplesoft FSCM':
            final = os.path.join(path_input, file)
            for data in os.listdir(final):
                if data.endswith('.pdf'):
                    final_path = os.path.join(final, data)
                    cv = Converter(final_path)
                    basename = os.path.splitext(data)[0]
                    cv.convert(path_output + '/' + file + '/' + basename+'.docx', start=0, end=None)
                    cv.close()
        elif file == 'React Developer':
            final = os.path.join(path_input, file)
            for data in os.listdir(final):
                if data.endswith('.pdf'):
                    final_path = os.path.join(final, data)
                    cv = Converter(final_path)
                    basename = os.path.splitext(data)[0]
                    cv.convert(path_output + '/' + file + '/' + basename+'.docx', start=0, end=None)
                    cv.close()
        elif file == 'React JS Developer':
            final = os.path.join(path_input, file)
            for data in os.listdir(final):
                if data.endswith('.pdf'):
                    final_path = os.path.join(final, data)
                    cv = Converter(final_path)
                    basename = os.path.splitext(data)[0]
                    cv.convert(path_output + '/' + file + '/' + basename+'.docx', start=0, end=None)
                    cv.close()
        elif file == 'SQL Developer Lightning insight':
            final = os.path.join(path_input, file)
            for data in os.listdir(final):
                if data.endswith('.pdf'):
                    final_path = os.path.join(final, data)
                    cv = Converter(final_path)
                    basename = os.path.splitext(data)[0]
                    cv.convert(path_output + '/' + file + '/' + basename+'.docx', start=0, end=None)
                    cv.close()
        elif file == 'workday resumes':
            final = os.path.join(path_input, file)
            for data in os.listdir(final):
                if data.endswith('.pdf'):
                    final_path = os.path.join(final, data)
                    cv = Converter(final_path)
                    basename = os.path.splitext(data)[0]
                    cv.convert(path_output + '/' + file + '/' + basename+'.docx', start=0, end=None)
                    cv.close()
# Out:
# [INFO] Start to convert C:/Users\Moin Dalvi\Data_Science\Projects\Resume_Classification\Resumes_pdf/Internship\Internship_Ravali_Musquare Technologies (1).pdf
# [INFO] [1/4] Opening document...
# [INFO] [2/4] Analyzing document...
# [INFO] [3/4] Parsing pages...
# [INFO] (1/4) Page 1
# [INFO] (2/4) Page 2
# [INFO] (3/4) Page 3
# [INFO] (4/4) Page 4
# [INFO] [4/4] Creating pages...
# [INFO] (1/4) Page 1
# [INFO] (2/4) Page 2
# [INFO] (3/4) Page 3
# [INFO] (4/4) Page 4
# [INFO] Terminated in 4.22s.
# [INFO] Start to convert C:/Users\Moin Dalvi\Data_Science\Projects\Resume_Classification\Resumes_pdf/Internship\Internship_Susovan Bag_Musquare Technologies.pdf
# [INFO] [1/4] Opening document...
# [INFO] [2/4] Analyzing document...
# [INFO] [3/4] Parsing pages...
# [INFO] (1/2) Page 1
# [INFO] (2/2) Page 2
# [INFO] [4/4] Creating pages...
# [INFO] (1/2) Page 1
# [INFO] (2/2) Page 2
# [INFO] Terminated in 0.35s.
# ...
